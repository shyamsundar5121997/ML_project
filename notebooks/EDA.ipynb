# %%
Diamond Price Prediction
Introduction About the Data :
The dataset The goal is to predict price of given diamond (Regression Analysis).

There are 10 independent variables (including id):

id : unique identifier of each diamond
carat : Carat (ct.) refers to the unique unit of weight measurement used exclusively to weigh gemstones and diamonds.
cut : Quality of Diamond Cut
color : Color of Diamond
clarity : Diamond clarity is a measure of the purity and rarity of the stone, graded by the visibility of these characteristics under 10-power magnification.
depth : The depth of diamond is its height (in millimeters) measured from the culet (bottom tip) to the table (flat, top surface)
table : A diamond's table is the facet which can be seen when the stone is viewed face up.
x : Diamond X dimension
y : Diamond Y dimension
x : Diamond Z dimension
Target variable:

price: Price of the given Diamond.
Dataset Source Link : https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv

# %%
import pandas as pd

# %%
## Data Ingestions step
df=pd.read_csv("C:/Users/SHYAMSUNDAR KARMAKAR/Downloads/train.csv/gemstone.csv")

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
# Save the dataset in notebooks ,dataset_name=gemstone
df.to_csv("gemstone.csv",index=False)

# %%
# Missing values check.
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
## Conclusion :- No missing values present in the dataset.

# %%
## Full description about the data set variables.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
## Descriptive Statistics about the Numerical variables.
df.describe().T
# Out:
#           count          mean           std    min       25%       50%
# id     193573.0  96786.000000  55879.856166    0.0  48393.00  96786.00  \
# carat  193573.0      0.790688      0.462688    0.2      0.40      0.70
# depth  193573.0     61.820574      1.081704   52.1     61.30     61.90
# table  193573.0     57.227675      1.918844   49.0     56.00     57.00
# x      193573.0      5.715312      1.109422    0.0      4.70      5.70
# y      193573.0      5.720094      1.102333    0.0      4.71      5.72
# z      193573.0      3.534246      0.688922    0.0      2.90      3.53
# price  193573.0   3969.155414   4034.374138  326.0    951.00   2401.00
#
#              75%        max
# id     145179.00  193572.00
# carat       1.03       3.50
# depth      62.40      71.60
# table      58.00      79.00
# x           6.51       9.65
# y           6.51      10.01
# z           4.03      31.30
# price    5408.00   18818.00

# %%
## Here 'id' column is unique value , so we drop the 'id' column.
df=df.drop(labels=['id'],axis=1)

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
## Conclusion : drop the 'id' cloumn from the dataset.

# %%
## Check for duplicated record.
df.duplicated().sum()
# Out:
# 0

# %%
## If any duplicated values are present in the dataset then use below code.
df.drop_duplicates().sum()

# %%
## segrigated(divided) the numerical and categorical columns.
numerical_columns=df.columns[df.dtypes!="object"]
categorical_columns=df.columns[df.dtypes=="object"]
print("Numerical columns is :" , numerical_columns)
print("Categorical columns is :" , categorical_columns)
# Out:
# Numerical columns is : Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')
# Categorical columns is : Index(['cut', 'color', 'clarity'], dtype='object')

# %%
## Why we segrigated Numerical & Categorical columns ?
# Ans : For the EDA purpose.

# %%
## describe for categorical columns.
df[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
## describe for numerical columns.
df[numerical_columns].describe().T
# Out:
#           count         mean          std    min     25%      50%      75%
# carat  193573.0     0.790688     0.462688    0.2    0.40     0.70     1.03  \
# depth  193573.0    61.820574     1.081704   52.1   61.30    61.90    62.40
# table  193573.0    57.227675     1.918844   49.0   56.00    57.00    58.00
# x      193573.0     5.715312     1.109422    0.0    4.70     5.70     6.51
# y      193573.0     5.720094     1.102333    0.0    4.71     5.72     6.51
# z      193573.0     3.534246     0.688922    0.0    2.90     3.53     4.03
# price  193573.0  3969.155414  4034.374138  326.0  951.00  2401.00  5408.00
#
#             max
# carat      3.50
# depth     71.60
# table     79.00
# x          9.65
# y         10.01
# z         31.30
# price  18818.00

# %%
## check for unique value in the particuler column.
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
## check for unique value in the particuler column in countable.
df['cut'].nunique()
# Out:
# 5

# %%
## check for unique value in the particuler column in countable.
df['color'].nunique()
# Out:
# 7

# %%
## check for unique value in the particuler column in countable.
df['clarity'].nunique()
# Out:
# 8

# %%
## check for unique value in the particuler column in each value how many times occures.
df['cut'].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
x=1
for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
## plot the all categorical features.
x=1
for i in categorical_columns:
    sns.countplot(data=df,x=i)
    print('\n')
    plt.show()

# %%
## correlation among the all numerical variables.
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
### Here we convert all categorical to numerical 
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map={"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map = {"I1":1,"SI2":2 ,"SI1":3 ,"VS2":4 , "VS1":5 , "VVS2":6 , "VVS1":7 ,"IF":8}

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map = {"D":1 ,"E":2 ,"F":3 , "G":4 ,"H":5 , "I":6, "J":7}

# %%
df['cut']=df['cut'].map(cut_map)
df['clarity'] = df['clarity'].map(clarity_map)
df['color'] = df['color'].map(color_map)

# %%
df.head()# first five obs.
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453
